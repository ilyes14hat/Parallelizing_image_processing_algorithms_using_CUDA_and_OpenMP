# %% [markdown]
# # Initialization

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:18:20_PST_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-it36xs8y
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-it36xs8y
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit aac710a35f52bb78ab34d2e52517237941399eff
#   Preparing metadata (setup.py) ... done

# %%
# %load_ext nvcc_plugin
# Out:
# The nvcc_plugin extension is already loaded. To reload it, use:
#   %reload_ext nvcc_plugin

# %% [markdown]
# # Success

# %% [markdown]
# ### Invert

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#               fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
# void invert(int theImageArray[1024][1024]){
#     for (int i = 1; i < MAX_HEIGHT; i++) {
#         for (int j = 1; j < MAX_WIDTH; j++) {
#             // Code pour inverser l'image
#             theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];theImageArray[i][j] = 255 - theImageArray[i][j];
#         }
#     }
# }
#
# __global__ void invert_cuda(int *theImageVector){
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     for (int i = i_start; i < i_end; i++){
#         theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];theImageVector[i] = 255 - theImageVector[i];
#     }
# }
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#         }
#     }
#
#     int* GPU_MAX_HEIGHT;
#     int* GPU_IMAGE_VECTOR;
#
#
#     for (int k=0; k < 11; k++)
#     {
#       start = clock();
#
#       invert(theImageArray);
#
#       end = clock();
#       time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#       cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#       cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#       start = clock();
#
#       invert_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR);
#
#       cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#       end = clock();
#       time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#       printf("\nParallel Time (CUDA) : %f \n     Sequential Time : %f\n", time_parallel, time_seq);
#     }
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#       for(int j = 0; j < MAX_WIDTH; j++){
#               theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#       }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     return 0 ;
# }
# Out:
# Parallel Time (CUDA) : 0.006271
#      Sequential Time : 0.116810
#
# Parallel Time (CUDA) : 0.006276
#      Sequential Time : 0.122668
#
# Parallel Time (CUDA) : 0.006192
#      Sequential Time : 0.116477
#
# Parallel Time (CUDA) : 0.006270
#      Sequential Time : 0.117133
#
# Parallel Time (CUDA) : 0.006243
#      Sequential Time : 0.116836
#
# Parallel Time (CUDA) : 0.006233
#      Sequential Time : 0.121384
#
# Parallel Time (CUDA) : 0.006233
#      Sequential Time : 0.114082
#
# Parallel Time (CUDA) : 0.006210
#      Sequential Time : 0.112821
#
# Parallel Time (CUDA) : 0.006218
#      Sequential Time : 0.112913
#
# Parallel Time (CUDA) : 0.006263
#      Sequential Time : 0.120277
#
# Parallel Time (CUDA) : 0.006218
#      Sequential Time : 0.118569

# %% [markdown]
# ### Threshold

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
# void threshold(int theImageArray[1024][1024], int n) {
#     for (int i = 0; i < MAX_HEIGHT; i++) {
#         for (int j = 0; j < MAX_WIDTH; j++) {
#           switch (n){
#             case 1:
#                 printf("Invalid response. Please start over. /n");
#                 break;
#
#             case 2:
#                 if (theImageArray[i][j] > (n-1)*255/n) {
#                     theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;
#                 }
#                 else {
#                     theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;
#                 }
#                 break;
#             case 3:
#                 if (theImageArray[i][j] > (n-1)*255/n) {
#                     theImageArray[i][j] = 255;
#                 }
#                 else if (theImageArray[i][j] > (n-2)*(255/n)){
#                     theImageArray[i][j] = (n-2)*(255/n);
#                 }
#                 else {
#                     theImageArray[i][j] = 0;
#                 }
#                 break;
#             case 4:
#                 if (theImageArray[i][j] > (n-1)*255/n) {
#                     theImageArray[i][j] = 255;
#                 }
#                 else if (theImageArray[i][j] > (n-2)*(255/n)){
#                     theImageArray[i][j] = (n-2)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-3)*(255/n)){
#                     theImageArray[i][j] = (n-3)*(255/n);
#                 }
#                 else {
#                     theImageArray[i][j] = 0;
#                 }
#                 break;
#             case 5:
#                 if (theImageArray[i][j] > (n-1)*255/n) {
#                     theImageArray[i][j] = 255;
#                 }
#                 else if (theImageArray[i][j] > (n-2)*(255/n)){
#                     theImageArray[i][j] = (n-2)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-3)*(255/n)){
#                     theImageArray[i][j] = (n-3)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-4)*(255/n)){
#                     theImageArray[i][j] = (n-4)*(255/n);
#                 }
#                 else {
#                     theImageArray[i][j] = 0;
#                 }
#                 break;
#             case 6:
#
#                 if (theImageArray[i][j] > (n-1)*255/n) {
#                     theImageArray[i][j] = 255;
#                 }
#                 else if (theImageArray[i][j] > (n-2)*(255/n)){
#                     theImageArray[i][j] = (n-2)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-3)*(255/n)){
#                     theImageArray[i][j] = (n-3)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-4)*(255/n)){
#                     theImageArray[i][j] = (n-4)*(255/n);
#                 }
#                 else if (theImageArray[i][j] > (n-5)*(255/n)){
#                     theImageArray[i][j] = (n-5)*(255/n);
#                 }
#                 else {
#                     theImageArray[i][j] = 0;
#                 }
#                 break;
#             default:
#                 printf("Invalid response. Please start over. /n");
#                 break;
#             }
#         }
#     }
# }
#
#
# __global__ void threshold_cuda(int *theImageVector, int* choix){
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     int n = *choix;
#     for (int i = i_start; i < i_end; i++){
#        switch (n){
#             case 1:
#                 printf("Invalid response. Please start over. /n");
#                 break;
#
#             case 2:
#                 if (theImageVector[i] > (n-1)*255/n) {
#                     theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#                 }
#                 else {
#                     theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#                 }
#                 break;
#             case 3:
#                 if (theImageVector[i] > (n-1)*255/n) {
#                     theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#                 }
#                 else if (theImageVector[i] > (n-2)*(255/n)){
#                     theImageVector[i] = (n-2)*(255/n);
#                 }
#                 else {
#                     theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#                 }
#                 break;
#             case 4:
#                 if (theImageVector[i] > (n-1)*255/n) {
#                     theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#                 }
#                 else if (theImageVector[i] > (n-2)*(255/n)){
#                     theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-3)*(255/n)){
#                     theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);
#                 }
#                 else {
#                     theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#                 }
#                 break;
#             case 5:
#                 if (theImageVector[i] > (n-1)*255/n) {
#                     theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#                 }
#                 else if (theImageVector[i] > (n-2)*(255/n)){
#                     theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-3)*(255/n)){
#                     theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-4)*(255/n)){
#                     theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);
#                 }
#                 else {
#                     theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#                 }
#                 break;
#             case 6:
#                 if (theImageVector[i] > (n-1)*255/n) {
#                     theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#                 }
#                 else if (theImageVector[i] > (n-2)*(255/n)){
#                     theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);theImageVector[i] = (n-2)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-3)*(255/n)){
#                     theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);theImageVector[i] = (n-3)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-4)*(255/n)){
#                     theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);theImageVector[i] = (n-4)*(255/n);
#                 }
#                 else if (theImageVector[i] > (n-5)*(255/n)){
#                     theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);theImageVector[i] = (n-5)*(255/n);
#                 }
#                 else {
#                     theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#                 }
#                 break;
#             default:
#                 printf("Invalid response. Please start over. /n");
#                 break;
#             }
#     }
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#         }
#     }
#
#     // you can change the value of choix. the allowed values [2, 6]
#     int choix = 2;
#
#     int* GPU_CHOIX;
#     int* GPU_IMAGE_VECTOR;
#
#     cudaMalloc ((void **) &GPU_CHOIX, size);
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#
#     for (int k=0; k < 10; k++)
#     {
#       start = clock();
#
#       threshold(theImageArray, choix);
#
#       end = clock();
#       time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#       start = clock();
#
#       cudaMemcpy (GPU_CHOIX, &choix, size, cudaMemcpyHostToDevice);
#       cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#       threshold_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR, GPU_CHOIX);
#
#       cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#       end = clock();
#       time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#       printf("\nParallel Time (CUDA) : %f \n     Sequential Time : %f\n", time_parallel, time_seq);
#     }
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#       for(int j = 0; j < MAX_WIDTH; j++){
#               theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#       }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     return 0;
# }
# Out:
# Parallel Time (CUDA) : 0.007746
#      Sequential Time : 0.078865
#
# Parallel Time (CUDA) : 0.007669
#      Sequential Time : 0.048815
#
# Parallel Time (CUDA) : 0.007612
#      Sequential Time : 0.041301
#
# Parallel Time (CUDA) : 0.007549
#      Sequential Time : 0.041347
#
# Parallel Time (CUDA) : 0.007550
#      Sequential Time : 0.041064
#
# Parallel Time (CUDA) : 0.007569
#      Sequential Time : 0.049784
#
# Parallel Time (CUDA) : 0.007626
#      Sequential Time : 0.041233
#
# Parallel Time (CUDA) : 0.007560
#      Sequential Time : 0.043012
#
# Parallel Time (CUDA) : 0.007644
#      Sequential Time : 0.042038
#
# Parallel Time (CUDA) : 0.007479
#      Sequential Time : 0.042741

# %% [markdown]
# ### Luminosity

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
#
# void luminosity(int theImageArray[1024][1024], int choix) {
#
#     float perc = 0.80;
#     // (Choix == 0) => lighten
#     // (Choix == 1) => Darken
#     if(choix == 0){
#         perc = 1.0 + perc;
#
#         for (int i = 0; i < MAX_HEIGHT; i++) {
#             for (int j = 0; j < MAX_WIDTH; j++) {
#                 if(perc*theImageArray[i][j]<= 255){
#                     theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];
#                 }
#                 else{
#                     theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;theImageArray[i][j] = 255;
#                 }
#             }
#         }
#     }
#
#     if(choix == 1){
#         perc = 1.0 - perc;
#
#         for (int i = 0; i < MAX_HEIGHT; i++) {
#             for (int j = 0; j < MAX_WIDTH; j++) {
#                 theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];theImageArray[i][j] = perc*theImageArray[i][j];
#             }
#         }
#     }
# }
#
#
# __global__ void luminosity_cuda(int *theImageVector, int* choix){
#
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     float perc = 0.80;
#     // (Choix == 0) => lighten
#     // (Choix == 1) => Darken
#
#
#      if(*choix == 0){
#         perc = 1.0 + perc;
#         for (int i = i_start; i < i_end; i++){
#             if(perc*theImageVector[i]<= 255){
#                 theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];
#             }
#             else{
#                 theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;theImageVector[i] = 255;
#             }
#         }
#     }
#
#      if(*choix == 1){
#         perc = 1.0 - perc;
#         for (int i = i_start; i < i_end; i++){
#             theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];theImageVector[i] = theImageVector[i]/perc;theImageVector[i] = perc*theImageVector[i];
#         }
#     }
#
#
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#         }
#     }
#
#     // you can change the value of choix. (choix = 0) => Lighten, (choix = 1) => darken
#     int choix = 1;
#
#     int* GPU_CHOIX;
#     int* GPU_IMAGE_VECTOR;
#
#     cudaMalloc ((void **) &GPU_CHOIX, size);
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#
#     for (int k=0; k < 11; k++)
#     {
#       start = clock();
#
#       luminosity(theImageArray, choix);
#
#       end = clock();
#       time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#       start = clock();
#       cudaMemcpy (GPU_CHOIX, &choix, size, cudaMemcpyHostToDevice);
#       cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#       luminosity_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR, GPU_CHOIX);
#
#       cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#       end = clock();
#       time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#       printf("\nParallel Time (CUDA) : %f \n     Sequential Time : %f\n", time_parallel, time_seq);
#     }
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#       for(int j = 0; j < MAX_WIDTH; j++){
#               theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#       }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     return 0 ;
# }
# Out:
# reading height=428, width=388
#
# Parallel Time (CUDA) : 0.021592
#      Sequential Time : 0.270415
#
# Parallel Time (CUDA) : 0.022207
#      Sequential Time : 0.269606
#
# Parallel Time (CUDA) : 0.022119
#      Sequential Time : 0.265377
#
# Parallel Time (CUDA) : 0.022147
#      Sequential Time : 0.270811
#
# Parallel Time (CUDA) : 0.022136
#      Sequential Time : 0.267214
#
# Parallel Time (CUDA) : 0.022214
#      Sequential Time : 0.267683
#
# Parallel Time (CUDA) : 0.022300
#      Sequential Time : 0.270782
#
# Parallel Time (CUDA) : 0.022158
#      Sequential Time : 0.268971
#
# Parallel Time (CUDA) : 0.022105
#      Sequential Time : 0.265377
#
# Parallel Time (CUDA) : 0.022177
#      Sequential Time : 0.284717
#
# Parallel Time (CUDA) : 0.022185
#      Sequential Time : 0.271985

# %% [markdown]
# ### Framing

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
#
# void frame(int theImageArray[1024][1024]){
#     int startPosX = 100;
#     int endPosX = 300;
#     int startPosY = 100;
#     int endPosY = 300;
#
#     for(int i = 0; i < MAX_WIDTH; i++){
#         for(int j = 0; j < startPosY; j++){
#             theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;
#         }
#     }
#     for(int i = 0; i < startPosX; i++){
#         for(int j = startPosY; j < MAX_HEIGHT; j++){
#             theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;
#         }
#     }
#     for(int i = startPosX; i < endPosX; i++){
#         for(int j = endPosY; j < MAX_HEIGHT; j++){
#             theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;
#         }
#     }
#     for(int i = endPosX; i < MAX_WIDTH; i++){
#         for(int j = startPosY; j < MAX_HEIGHT; j++){
#             theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;theImageArray[i][j] = 0;
#         }
#     }
#
# }
#
# __global__ void frame_cuda(int* theImageVector){
#     // changer
#     int startPosX = 100;
#     int endPosX = 300;
#     int startPosY = 100;
#     int endPosY = 300;
#
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     int pos_i;
#     int pos_j;
#     for (int i = i_start; i < i_end; i++){
#         pos_i = i / 1024;
#         pos_j = i % 1024;
#         if(pos_i < startPosY || pos_i > endPosY || pos_j < startPosX || pos_j > endPosX){
#             theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;theImageVector[i] = 0;
#         }
#     }
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#         }
#     }
#
#
#     int* GPU_IMAGE_VECTOR;
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#
#     for (int k=0; k<11 ; k++)
#     {
#       start = clock();
#
#       frame(theImageArray);
#
#       end = clock();
#       time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#       start = clock();
#
#       cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#       frame_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR);
#
#       cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#       end = clock();
#       time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#       printf("\nParallel Time (CUDA) : %f \n     Sequential Time : %f\n", time_parallel, time_seq);
#     }
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#       for(int j = 0; j < MAX_WIDTH; j++){
#               theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#       }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     return 0 ;
# }
# Out:
# Parallel Time (CUDA) : 0.005532
#      Sequential Time : 0.070529
#
# Parallel Time (CUDA) : 0.005526
#      Sequential Time : 0.068720
#
# Parallel Time (CUDA) : 0.005586
#      Sequential Time : 0.070913
#
# Parallel Time (CUDA) : 0.005503
#      Sequential Time : 0.071175
#
# Parallel Time (CUDA) : 0.005588
#      Sequential Time : 0.071176
#
# Parallel Time (CUDA) : 0.005658
#      Sequential Time : 0.071205
#
# Parallel Time (CUDA) : 0.005540
#      Sequential Time : 0.071616
#
# Parallel Time (CUDA) : 0.005542
#      Sequential Time : 0.071224
#
# Parallel Time (CUDA) : 0.004616
#      Sequential Time : 0.070800
#
# Parallel Time (CUDA) : 0.005641
#      Sequential Time : 0.067019
#
# Parallel Time (CUDA) : 0.005605
#      Sequential Time : 0.064446

# %% [markdown]
# # Failure

# %% [markdown]
# ## Transformation

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
#
# void vertical_transformation(int theImageArray[1024][1024], int theImageArrayDup[1024][1024], int width, int height){
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];theImageArrayDup[i][j] = theImageArray[width-i][j];
#     }
#   }
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];theImageArray[i][j] = theImageArrayDup[i][j];
#     }
#   }
#
# }
#
# __global__ void vertical_transformation_cuda(int* theImageVector, int* theImageVectorDup, int* width, int* height){
#
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     int pos_i;
#     int pos_j;
#
#     for (int i = i_start; i < i_end; i++){
#         pos_i = i / 1024;
#         pos_j = i % 1024;
#         if (pos_i < *width && pos_j < *height){
#             theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];theImageVectorDup[i] = theImageVector[(*width - pos_i)*1024 + pos_j];
#          }
#     }
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#     int* theImageVectorDup = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#             theImageVectorDup[i*MAX_WIDTH + j] = 255;
#         }
#     }
#
#
#     int* GPU_IMAGE_VECTOR;
#     int* GPU_IMAGE_VECTOR_DUP;
#     int* GPU_HEIGHT;
#     int* GPU_WIDTH;
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR_DUP, 1024*1024*sizeof(int));
#     cudaMalloc ((void **) &GPU_HEIGHT, sizeof(int));
#     cudaMalloc ((void **) &GPU_WIDTH, sizeof(int));
#
#     start = clock();
#
#     vertical_transformation(theImageArray, theImageArrayDup, width, height);
#
#     end = clock();
#     time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#     start = clock();
#
#
#     cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#     cudaMemcpy (GPU_IMAGE_VECTOR_DUP, theImageVectorDup, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#     cudaMemcpy (GPU_HEIGHT, &height, size, cudaMemcpyHostToDevice);
#     cudaMemcpy (GPU_WIDTH, &width, size, cudaMemcpyHostToDevice);
#
#     vertical_transformation_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR, GPU_IMAGE_VECTOR_DUP, GPU_WIDTH, GPU_HEIGHT);
#
#     cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR_DUP, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#     end = clock();
#     time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#         }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     printf ( "Copying %s to %s, height=%u, width=%u, maxPixel=%d, \ntemps parallele %f \ntemps sequentielle %f\n", pgmInFileName,
#              pgmOutFileName,
#              height, width, maxPixel , time_parallel, time_seq) ;
#
#     return 0 ;
# }
# Out:
# reading height=428, width=388
# Copying irv.pgm to irv_out.pgm, height=428, width=388, maxPixel=255, 0.037007 , 0.026579

# %% [markdown]
# ## Rotate 90

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
#
# void rotate_90(int theImageArray[1024][1024], int theImageArrayDup[1024][1024], int width, int height){
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArrayDup[i][j] = theImageArray[i][height - j];
#     }
#   }
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArray[i][j] = theImageArrayDup[i][j];
#     }
#   }
#
# }
#
# __global__ void rotate_90_cuda(int* theImageVector, int* theImageVectorDup, int* width, int* height){
#
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     int pos_i;
#     int pos_j;
#
#     for (int i = i_start; i < i_end; i++){
#         pos_i = i / 1024;
#         pos_j = i % 1024;
#         if (pos_i < *width && pos_j < *height){
#             theImageVectorDup[i] = theImageVector[(*width - pos_j)*1024 + pos_i];
#          }
#     }
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#     int* theImageVectorDup = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#             theImageVectorDup[i*MAX_WIDTH + j] = 255;
#         }
#     }
#
#
#     int* GPU_IMAGE_VECTOR;
#     int* GPU_IMAGE_VECTOR_DUP;
#     int* GPU_HEIGHT;
#     int* GPU_WIDTH;
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#     cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR_DUP, 1024*1024*sizeof(int));
#     cudaMemcpy (GPU_IMAGE_VECTOR_DUP, theImageVectorDup, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_HEIGHT, sizeof(int));
#     cudaMemcpy (GPU_HEIGHT, &height, size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_WIDTH, sizeof(int));
#     cudaMemcpy (GPU_WIDTH, &width, size, cudaMemcpyHostToDevice);
#
#     start = clock();
#
#     rotate_90(theImageArray, theImageArrayDup, width, height);
#
#     end = clock();
#     time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#     start = clock();
#
#     rotate_90_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR, GPU_IMAGE_VECTOR_DUP, GPU_WIDTH, GPU_HEIGHT);
#
#     cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR_DUP, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#
#     end = clock();
#     time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#         }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     printf ( "Copying %s to %s, height=%u, width=%u, maxPixel=%d, \ntemps parallele %f \ntemps sequentielle %f\n", pgmInFileName,
#              pgmOutFileName,
#              height, width, maxPixel , time_parallel, time_seq) ;
#
#     return 0 ;
# }
# Out:
# Copying irv.pgm to irv_out.pgm, height=428, width=388, maxPixel=255,
# temps parallele 0.001989
# temps sequentielle 0.001012

# %% [markdown]
# ## Horizontal Transformation

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <stdbool.h>
# #include <string.h>
# #include <time.h>
#
# #define MAX_HEIGHT 1024
# #define MAX_WIDTH 1024
#
#
# #define MAX_PIXELS_PER_LINE 25
#
# #define MIN( x, y ) ( ( x ) < ( y ) ? ( x ) : ( y ) )
#
#
#
# int theImageArray[1024][MAX_WIDTH];
# int theImageArrayDup[1024][MAX_WIDTH];
#
#
# FILE* read_pgm_file_info
# (
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmFname
# )
# {
#     static FILE* fp = 0L ;
#     char pgmFormatFlag[3] =  { '\0' } ;
#
#     char trash[80] = { '\0' } ;
#     memset ( ( void * ) trash, '\0', 80 ) ;
#
#     fp = fopen ( pgmFname, "r" ) ;
#
#     if ( fp )
#     {
#
#         fscanf ( fp, "%2c\n", pgmFormatFlag ) ;
#         if(1)
#         {
#             fscanf ( fp, "%i", width ) ;
#
#             fscanf ( fp, "%i", height ) ;
#
#             fscanf ( fp, "%i", maxPixel ) ;
#         }
#     }
#
#
#     return fp ;
# }
#
#
# void write_pgm_file_from_array
# (
#     char* pgmOutFileName,
#     int imageArray[][MAX_WIDTH],
#     char* commentLine,
#     int height,
#     int width,
#     int maxPixel
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = fopen ( pgmOutFileName, "w" ) ;
#     if ( fp )
#     {
#         fprintf ( fp, "P2\n" ) ;
#         fprintf ( fp, "%u %u\n", width, height ) ;
#         fprintf ( fp, "%u\n", maxPixel ) ;
#
#         for ( row = 0 ; row < height ; row ++ )
#         {
#             for ( col = 0 ; col < width ; col ++ )
#             {
#
#                 fprintf ( fp, "%u", imageArray[row][col] ) ;
#                 if ( MAX_PIXELS_PER_LINE > 1 )
#                 {
#                     fprintf ( fp, " " ) ;
#                 }
#                 if ( ( col % MAX_PIXELS_PER_LINE ) == 0 )
#                 {
#                     fprintf ( fp, "\n" ) ;
#                 }
#             }
#             if ( col % MAX_PIXELS_PER_LINE )
#             {
#                 fprintf ( fp, "\n" ) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#     return ;
# }
#
#
# void read_pgm_file_into_array
# (
#     int imageArray[][MAX_WIDTH],
#     int* height,
#     int* width,
#     int* maxPixel,
#     char* pgmInFileName
# )
# {
#     int row = 0 ;
#     int col = 0 ;
#     FILE* fp = read_pgm_file_info( height, width, maxPixel, pgmInFileName );
#     char trash = ' ';
#     char yesThreshold = ' ';
#
#     if ( fp )
#     {
#         for ( row = 0 ; row < MIN( MAX_HEIGHT - 1, *height ) ; row ++ )
#         {
#             for ( col = 0 ; col < MIN( MAX_WIDTH -1, *width ) ; col ++ )
#             {
#                 fscanf ( fp, "%i", &imageArray[row][col]) ;
#             }
#         }
#         fclose ( fp ) ;
#     }
#
#     return ;
# }
#
#
# void transform_horizontal(int theImageArray[1024][1024], int theImageArrayDup[1024][1024], int width, int height){
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArrayDup[i][j] = theImageArray[i][height - j];
#     }
#   }
#
#   for(int i = 0; i < width; i++){
#     for(int j = 0; j < height; j++){
#         theImageArray[i][j] = theImageArrayDup[i][j];
#     }
#   }
#
# }
#
# __global__ void transform_horizontal_cuda(int* theImageVector, int* theImageVectorDup, int* width, int* height){
#
#     int i_start = threadIdx.x * blockDim.x;
#     int i_end = i_start + 1024;
#     int pos_i;
#     int pos_j;
#
#     for (int i = i_start; i < i_end; i++){
#         pos_i = i / 1024;
#         pos_j = i % 1024;
#         if (pos_i < *width && pos_j < *height){
#             theImageVectorDup[i] = theImageVector[pos_i * 1024 + *height - pos_j];
#          }
#     }
# }
#
#
#
# int main( void )
# {
#     int height  = 0 ;
#     int width = 0 ;
#     int maxPixel = 0 ;
#
#     clock_t start, end;
#     double time_parallel,time_seq;
#
#     char* pgmInFileName = "irv.pgm" ;
#     char* pgmOutFileName = "irv_out.pgm" ;
#
#
#     read_pgm_file_into_array(theImageArray, &height, &width, &maxPixel, pgmInFileName ) ;
#
#
#     int size = sizeof(int);
#     int* theImageVector = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#     int* theImageVectorDup = (int *) malloc (MAX_HEIGHT*MAX_WIDTH*size);
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArrayDup[i][j] = theImageArray[i][j];
#             theImageVector[i*MAX_WIDTH + j] = theImageArray[i][j];
#             theImageVectorDup[i*MAX_WIDTH + j] = 255;
#         }
#     }
#
#
#     int* GPU_IMAGE_VECTOR;
#     int* GPU_IMAGE_VECTOR_DUP;
#     int* GPU_HEIGHT;
#     int* GPU_WIDTH;
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR, 1024*1024*sizeof(int));
#     cudaMemcpy (GPU_IMAGE_VECTOR, theImageVector, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_IMAGE_VECTOR_DUP, 1024*1024*sizeof(int));
#     cudaMemcpy (GPU_IMAGE_VECTOR_DUP, theImageVectorDup, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_HEIGHT, sizeof(int));
#     cudaMemcpy (GPU_HEIGHT, &height, size, cudaMemcpyHostToDevice);
#
#     cudaMalloc ((void **) &GPU_WIDTH, sizeof(int));
#     cudaMemcpy (GPU_WIDTH, &width, size, cudaMemcpyHostToDevice);
#
#     start = clock();
#
#     transform_horizontal(theImageArray, theImageArrayDup, width, height);
#
#     end = clock();
#     time_seq = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#
#     start = clock();
#
#     transform_horizontal_cuda<<<1, MAX_WIDTH>>>(GPU_IMAGE_VECTOR, GPU_IMAGE_VECTOR_DUP, GPU_WIDTH, GPU_HEIGHT);
#
#
#     cudaMemcpy (theImageVector, GPU_IMAGE_VECTOR_DUP, MAX_HEIGHT*MAX_WIDTH*size, cudaMemcpyDeviceToHost);
#      end = clock();
#     time_parallel = ((double) (end - start)) /CLOCKS_PER_SEC;
#
#     for(int i = 0; i < MAX_HEIGHT; i++){
#         for(int j = 0; j < MAX_WIDTH; j++){
#             theImageArray[i][j] = theImageVector[i*MAX_WIDTH + j];
#         }
#     }
#
#     write_pgm_file_from_array ( pgmOutFileName, theImageArray, "# JR test file", height, width,
#                                 maxPixel ) ;
#
#     printf ( "Copying %s to %s, height=%u, width=%u, maxPixel=%d, \ntemps parallele %f \ntemps sequentielle %f\n", pgmInFileName,
#              pgmOutFileName,
#              height, width, maxPixel , time_parallel, time_seq) ;
#
#     return 0 ;
# }
# Out:
# reading height=428, width=388
# Copying irv.pgm to irv_out.pgm, height=428, width=388, maxPixel=255, 0.000023 , 0.002049
